# %% [markdown]
# # Migración de información patrimonio

# %%
# %pip install pandas
# %pip install psycopg2
# %pip install openpyxl
# Out:
# Requirement already satisfied: pandas in c:\users\quipu-q2004e-24\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\quipu-q2004e-24\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\quipu-q2004e-24\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\quipu-q2004e-24\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\quipu-q2004e-24\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\quipu-q2004e-24\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: psycopg2 in c:\users\quipu-q2004e-24\appdata\local\programs\python\python313\lib\site-packages (2.9.10)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: openpyxl in c:\users\quipu-q2004e-24\appdata\local\programs\python\python313\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\quipu-q2004e-24\appdata\local\programs\python\python313\lib\site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Carga de archivo de usuarios

# %%
import pandas as pd

# %%
data = pd.read_excel("ultimos_correlativos.xlsx")

# %% [markdown]
# ## Separacion segun el tipo de Bien

# %% [markdown]
# ### Bienes ingresados por OC

# %%
data_oc = data[data["compra"].notna()]

# %%
filas, columnas = data_oc.shape
print("Bienes ingresados por OC")
print('Columnas',columnas)
print('Filas',filas)
# Out:
# Bienes ingresados por OC
# Columnas 124
# Filas 1118

# %% [markdown]
# ### Bienes ingresados por NEA

# %%
data_nea =  data[data["npecosa"].notna()]

# %%
filas, columnas  = data_nea.shape
print("Bienes ingresados por NEA")
print('Columnas',columnas)
print('Filas',filas)
# Out:
# Bienes ingresados por NEA
# Columnas 124
# Filas 1690

# %% [markdown]
# ### Bienes sin NEA ni OC

# %%
data_null = data[(data["npecosa"].isnull()) & (data["compra"].isnull())]

# %%
filas, columnas = data_null.shape
print("Bienes sin OC ni NEA")
print('Columnas',columnas)
print('Filas',filas)
# Out:
# Bienes sin OC ni NEA
# Columnas 124
# Filas 231

# %%
data_oc.to_excel("ultimos_correlativos_oc.xlsx")
data_nea.to_excel("ultimos_correlativos_nea.xlsx")
data_null.to_excel("ultimos_correlativos_null.xlsx")

# %% [markdown]
# ## Busqueda de persona encargada de un bien en la base de datos

# %% [markdown]
# ### Busqueda de persona encargada por OC

# %%
import psycopg2
import psycopg2.extras

# Connect to the PostgreSQL database
conn = psycopg2.connect(
    dbname="bytsscom_unmsm",
    user="postgres",
    password="postgres",
    host="localhost",
    port="5432"
)
cur = conn.cursor(cursor_factory=psycopg2.extras.DictCursor)

# %%
result = cur.execute("SELECT * FROM  bytsscom_bytcore.vw_persona")

# %%
result = cur.fetchall()

# %%
result
# Out:
# [[146958,
#   'N',
#   113,
#   '74829837',
#   'BARRENECHEA',
#   'BENITES',
#   'BALYA AGNES',
#   'BARRENECHEA BENITES, BALYA AGNES',
#   None,
#   'S',
#   'F',
#   datetime.date(2003, 2, 14),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'74829837':5 'agnes':4 'baly':3 'barreneche':1 'benit':2",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [150389,
#   'N',
#   113,
#   '72406431',
#   'MEDINA',
#   'ARELLANO',
#   'ANGEL OMAR',
#   'MEDINA ARELLANO, ANGEL OMAR',
#   None,
#   'S',
#   'M',
#   datetime.date(2004, 9, 17),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'72406431':5 'angel':3 'arellan':2 'medin':1 'omar':4",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [150396,
#   'N',
#   113,
#   '70052561',
#   'VENTOSILLA',
#   'TOLENTINO',
#   'JERSON LUIS',
#   'VENTOSILLA TOLENTINO, JERSON LUIS',
#   None,
#   'S',
#   'M',
#   datetime.date(1999, 4, 24),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'70052561':5 'jerson':3 'luis':4 'tolentin':2 'ventosill':1",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [150397,
#   'J',
#   114,
#   '20523397070',
#   None,
#   None,
#   'NEGOCIACIONES & FERRETERIA DANTE EIRL',
#   'NEGOCIACIONES & FERRETERIA DANTE EIRL',
#   'VIA EVITAMIENTO KM 6.5 INT. 29 LIMA-LIMA-RIMAC',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20523397070',
#   'S',
#   3705,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20523397070':5 'dant':3 'eirl':4 'ferreteri':2 'negoci':1",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [162303,
#   'N',
#   113,
#   '19083600',
#   'HIPÓLITO',
#   'MARTINEZ',
#   'FELIPE TOMAS',
#   'HIPÓLITO MARTINEZ, FELIPE TOMAS',
#   'CALLE 29 DE JUNIO 1544 - FLORENCIA DE MORA -TRUJILLO - LA LIBERTAD',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10190836008',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'19083600':5 'felip':3 'hipolit':1 'martinez':2 'tom':4",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [150401,
#   'N',
#   113,
#   '74494021',
#   'RAMIREZ',
#   'LIMAYLLA',
#   'DARLENE',
#   'RAMIREZ LIMAYLLA, DARLENE',
#   None,
#   'S',
#   'F',
#   None,
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'74494021':4 'darlen':3 'limayll':2 'ramirez':1",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [150406,
#   'J',
#   114,
#   '20607395871',
#   None,
#   None,
#   'La Casita de la Repostería Sociedad Anónima Cerrada',
#   'La Casita de la Repostería Sociedad Anónima Cerrada',
#   'Leoncio Prado 816 - - 2do piso',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20607395871',
#   'S',
#   3697,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20607395871':9 'anonim':7 'casit':2 'cerr':8 'repost':5 'socied':6",
#   '0',
#   'RUC',
#   '1',
#   None,
#   'Jirón',
#   None,
#   'RUC'],
#  [150407,
#   'N',
#   113,
#   '08028346',
#   'Vargas',
#   'Suyón',
#   'Alfredo Abraham',
#   'Jirón Vargas Suyón, Alfredo Abraham',
#   'Coronel Leoncio Prado 751 - Urb. Orbea - Mercado Municipal de Magdalena',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10080283461',
#   'N',
#   3697,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'08028346':5 'abraham':4 'alfred':3 'suyon':2 'varg':1",
#   '0',
#   'DNI',
#   '1',
#   None,
#   'Jirón',
#   None,
#   'DNI'],
#  [150408,
#   'N',
#   113,
#   '72839950',
#   'Valle',
#   'Travezaño',
#   'Marlon Jair',
#   'Valle Travezaño, Marlon Jair',
#   'Las Malvas 132',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10728399509',
#   'N',
#   3680,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'72839950':5 'jair':4 'marlon':3 'travezañ':2 'vall':1",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [150409,
#   'J',
#   114,
#   '20609306573',
#   None,
#   None,
#   'M & G Grupo Candiotti S.A.C.',
#   'M & G Grupo Candiotti S.A.C.',
#   'Salvador Allende 495 Sector El Brillante - Pamplona Alta Mz.98 lote 22 A',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20609306573',
#   'S',
#   3710,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20609306573':6 'candiotti':4 'g':2 'grup':3 'm':1 's.a.c':5",
#   '0',
#   'RUC',
#   '1',
#   None,
#   'Avenida',
#   None,
#   'RUC'],
#  [150325,
#   'J',
#   114,
#   '10094816012',
#   None,
#   None,
#   'CALDERON MURGA LUIS ENRIQUE',
#   'CALDERON MURGA LUIS ENRIQUE',
#   'NRO 610 AV. PASO DE LOS ANDES PUEBLO LIBRE (MAGDALENA VIEJA) LIMA -LIMA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10094816012',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10094816012':5 'calderon':1 'enriqu':4 'luis':3 'murg':2",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [150410,
#   'N',
#   113,
#   '41167643',
#   'GUTIERREZ',
#   'CANALES',
#   'MARIO RAUL',
#   'GUTIERREZ CANALES, MARIO RAUL',
#   'AV. GRL SALAVERRY  690 - JESUS MARIA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10411676434',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'41167643':5 'canal':2 'gutierrez':1 'mari':3 'raul':4",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [150411,
#   'J',
#   114,
#   '20610988254',
#   None,
#   None,
#   'GRUPO FAVAS S.A.C.',
#   'GRUPO FAVAS S.A.C.',
#   'CAL.LOS CIPRESES NRO. 296 URB. CANTO BELLO LIMA - LIMA - SAN JUAN DE LURIGANCHO',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20610988254',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20610988254':4 'fav':2 'grup':1 's.a.c':3",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [150412,
#   'J',
#   114,
#   '20610681426',
#   None,
#   None,
#   'SOLUTION ANMAR CORP E.I.R.L.',
#   'SOLUTION ANMAR CORP E.I.R.L.',
#   'CAL.RIO TARICA NRO. 5148 DPTO. 303 URB. VILLA DEL NORTE LIMA - LIMA - LOS OLIVOS',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20610681426',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20610681426':5 'anmar':2 'corp':3 'e.i.r.l':4 'solution':1",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [129608,
#   'N',
#   114,
#   '10256754431',
#   'LAZARO',
#   'MANRIQUE',
#   'HUGO EFRAIN',
#   'LAZARO MANRIQUE, HUGO EFRAIN',
#   'JR. BELGRANO NRO 180 LIMA LIMA PUEBLO LIBRE (MAGDALENA VIEJA)',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10256754431',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10256754431':5 'efrain':4 'hug':3 'lazar':1 'manriqu':2",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [150413,
#   'N',
#   115,
#   '001422186',
#   'JIANWEI',
#   None,
#   'CHEN',
#   'JIANWEI , CHEN',
#   'AV. MARISCAL CÁCERES N.° 199, URB. VALDIVIESO - ATE - LIMA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '15602154014',
#   'N',
#   3680,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'001422186':3 'chen':2 'jianwei':1",
#   '0',
#   'CE',
#   '1',
#   None,
#   None,
#   None,
#   'CE'],
#  [150414,
#   'J',
#   114,
#   '20602528350',
#   None,
#   None,
#   'DREI ECKE S.A.C.',
#   'DREI ECKE S.A.C.',
#   'CAL. ENRIQUE PALACIOS NRO. 1066',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20602528350',
#   'S',
#   3699,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20602528350':4 'drei':1 'ecke':2 's.a.c':3",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [150417,
#   'J',
#   114,
#   '20607022845',
#   None,
#   None,
#   'CORPORACION FERRETERA SANTAMARIA E.I.R.L.',
#   'CORPORACION FERRETERA SANTAMARIA E.I.R.L.',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20607022845',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20607022845':5 'corporacion':1 'e.i.r.l':4 'ferreter':2 'santamari':3",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [150422,
#   'J',
#   114,
#   '20563046571',
#   None,
#   None,
#   'INVERSIONES WMB SAC',
#   'INVERSIONES WMB SAC',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20563046571',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20563046571':4 'inversion':1 'sac':3 'wmb':2",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [150426,
#   'J',
#   114,
#   '20601675839',
#   None,
#   None,
#   'FERRETERIA SAN ANTONIO & NICK E.I.R.L.',
#   'FERRETERIA SAN ANTONIO & NICK E.I.R.L.',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20601675839',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20601675839':6 'antoni':3 'e.i.r.l':5 'ferreteri':1 'nick':4 'san':2",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [150430,
#   'N',
#   113,
#   '73966932',
#   'RAYO',
#   'PADILLA',
#   'LEO YERSON',
#   'RAYO PADILLA, LEO YERSON',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10739669320',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'73966932':5 'leo':3 'padill':2 'ray':1 'yerson':4",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [150432,
#   'N',
#   113,
#   '44890495',
#   'CALDERON',
#   'RIOS',
#   'MARTHA STEFFANY',
#   'CALDERON RIOS, MARTHA STEFFANY',
#   'CAL. MANUEL PEREZ DE TUDELA Nro. 3373 URB. POP CONDEVILLA DEL SEÑOR LIMA - LIMA - SMP',
#   None,
#   'F',
#   None,
#   0,
#   None,
#   None,
#   '10448904950',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'44890495':5 'calderon':1 'marth':3 'rios':2 'steffany':4",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [150400,
#   'N',
#   113,
#   '76122615',
#   'JARAMIOS',
#   'CONDE',
#   'ESTHER ROSALINA',
#   'JARAMIOS CONDE, ESTHER ROSALINA',
#   None,
#   'S',
#   'F',
#   datetime.date(1998, 12, 17),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'76122615':5 'cond':2 'esther':3 'jarami':1 'rosalin':4",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [151314,
#   'N',
#   113,
#   '72907756',
#   'VALLE',
#   'ZUÑIGA',
#   'FABIANA BETZABE',
#   'VALLE ZUÑIGA, FABIANA BETZABE',
#   None,
#   'S',
#   'F',
#   datetime.date(2002, 5, 15),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'72907756':5 'betzab':4 'fabian':3 'vall':1 'zuñig':2",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [151322,
#   'J',
#   114,
#   '10101274441',
#   None,
#   None,
#   'ESPINOZA HERRERA LUCY ESTELA',
#   'ESPINOZA HERRERA LUCY ESTELA',
#   'MZ X LOTE 10 URB SAN CARLOS - SAN JUAN DE LURIGANCHO',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10101274441',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10101274441':5 'espinoz':1 'estel':4 'herrer':2 'lucy':3",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [152847,
#   'N',
#   113,
#   '29658872',
#   'ADRIAN',
#   'CORIPUNA',
#   'JAVIER ANTONIO',
#   'ADRIAN CORIPUNA, JAVIER ANTONIO',
#   'AV. JACARANDA Nro 330 Interior 402  URB. VALLE HERMOSO DE MONTERRI  SANTIAGO DE SURCO',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10296588721',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'29658872':5 'adri':1 'antoni':4 'coripun':2 'javi':3",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [132246,
#   'J',
#   114,
#   '10417832250',
#   None,
#   None,
#   'CHURAMPI MUNGUIA RODOLFO MASIAS',
#   'CHURAMPI MUNGUIA RODOLFO MASIAS',
#   'AV PALMERAS NRO 4312 CUETO FERNANDINI ET2 LOS OLIVOS',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10417832250',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10417832250':5 'churampi':1 'masi':4 'mungui':2 'rodolf':3",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [90974,
#   'J',
#   114,
#   '10407447315',
#   None,
#   None,
#   'QUISPE APAZA EVANGELINA',
#   'QUISPE APAZA EVANGELINA',
#   'CAL. JOSE CORONADO NRO. 648 LIMA - LIMA - LA VICTORIA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10407447315',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10407447315':4 'apaz':2 'evangelin':3 'quisp':1",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [152867,
#   'J',
#   114,
#   '20522976483',
#   None,
#   None,
#   'MPC COMPANY S.A.C.',
#   'MPC COMPANY S.A.C.',
#   'GRAL ARTIGAS NRO. 675 (ALT. CDRA 10 DE LA AV BOLIVAR) LIMA - LIMA - PUEBLO LIBRE (MAGDALENA VIEJA)',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20522976483',
#   'S',
#   3698,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20522976483':4 'company':2 'mpc':1 's.a.c':3",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [146892,
#   'J',
#   114,
#   '20601832411',
#   None,
#   None,
#   'FERRETERIA ,MIRIAN E.I.R.L',
#   'FERRETERIA ,MIRIAN E.I.R.L',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20601832411',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20601832411':4 'e.i.r.l':3 'ferreteri':1 'miri':2",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [146893,
#   'N',
#   113,
#   '72433309',
#   'MORE',
#   'CERRON',
#   'JOHAN JEAN PIERRE',
#   'MORE CERRON, JOHAN JEAN PIERRE',
#   None,
#   'S',
#   'M',
#   None,
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'72433309':6 'cerron':2 'jean':4 'joh':3 'mor':1 'pierr':5",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [146894,
#   'N',
#   113,
#   '72411205',
#   'PACHECO',
#   'CARBAJAL',
#   'XIOMARA INES',
#   'PACHECO CARBAJAL, XIOMARA INES',
#   None,
#   'S',
#   'F',
#   datetime.date(2004, 4, 28),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'72411205':5 'carbajal':2 'ines':4 'pachec':1 'xiom':3",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [146945,
#   'J',
#   114,
#   '10478218066',
#   None,
#   None,
#   'MONTES REYMONDEZ ANICETA',
#   'MONTES REYMONDEZ ANICETA',
#   'CAL. LOS CIPRECES Mz. N lote.25 ASOC FELIX RAUCANA (A 1 CUADRA DEL MERCADO MODELO DE RAUCANA) ATE-LIMA-LIMA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10478218066',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10478218066':4 'anicet':3 'mont':1 'reymondez':2",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [75453,
#   'N',
#   113,
#   '07338265',
#   'LEYTON',
#   'VALENCIA',
#   'IMELDA BEATRIZ',
#   'LEYTON VALENCIA, IMELDA BEATRIZ',
#   'AV. GRAL GARZON NRO. 1949 LIMA - LIMA - JESUS MARIA',
#   None,
#   'F',
#   None,
#   0,
#   None,
#   None,
#   '10073382659',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'07338265':5 'beatriz':4 'imeld':3 'leyton':1 'valenci':2",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [146995,
#   'J',
#   114,
#   '20607721646',
#   None,
#   None,
#   'MEGA ESTACION DE SERVICIO LOS DELFINES S.A.',
#   'MEGA ESTACION DE SERVICIO LOS DELFINES S.A.',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20607721646',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20607721646':8 'delfin':6 'estacion':2 'meg':1 's.a':7 'servici':4",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [74383,
#   'N',
#   113,
#   '06807628',
#   'LIMO',
#   'SALAZAR',
#   'JUAN FRANCISCO',
#   'LIMO SALAZAR, JUAN FRANCISCO',
#   'CAL.PIURA NRO. 852 DPTO. 402 URB. EL ROSARIO SANTA CRUZ (ALT CDRA 4 AV CMDTE ESPINAR)LIMA - LIMA - MIRAFLORES',
#   None,
#   'M',
#   None,
#   0,
#   None,
#   None,
#   '10068076281',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'06807628':5 'francisc':4 'juan':3 'lim':1 'salaz':2",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [146948,
#   'J',
#   114,
#   '20432719112',
#   None,
#   None,
#   'CORPORACION ALVA S.A.C.',
#   'CORPORACION ALVA S.A.C.',
#   'JR. HIPOLITO UNANUE NRO. 1568 INT. 109 (PARQUE CANEPA) LIMA - LIMA - LA VICTORIA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20432719112',
#   'S',
#   3692,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20432719112':4 'alva':2 'corporacion':1 's.a.c':3",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [146952,
#   'J',
#   114,
#   '20609242524',
#   None,
#   None,
#   'TECNOLOGIA Y GESTION PERU S.A.C.',
#   'TECNOLOGIA Y GESTION PERU S.A.C.',
#   'CAL.CRÉDITO NRO. 103 DPTO. 302 URB. EL BANCO DE JAVIER PRADO LIMA - LIMA - ATE',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20609242524',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20609242524':6 'gestion':3 'peru':4 's.a.c':5 'tecnologi':1",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [146955,
#   'J',
#   114,
#   '20602711863',
#   None,
#   None,
#   'ARIANA AG E.I.R.L.',
#   'ARIANA AG E.I.R.L.',
#   'MZA. E LOTE. 26 PROVIV EL OLIVAR IV DE CARABAYLLO (AV. UNIVERSITARIA PARAD. LINEA STA CRUZ) LIMA - LIMA - CARABAYLLO',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20602711863',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20602711863':4 'ag':2 'arian':1 'e.i.r.l':3",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [141670,
#   'N',
#   113,
#   '25411205',
#   'CARDENAS',
#   'POMAREDA',
#   'ROLANDO ALBERTO',
#   'CARDENAS POMAREDA, ROLANDO ALBERTO',
#   'AV. LOS PATRIOTAS Nro 550, Int. 101 - URB. MARANGA - SAN MIGUEL ',
#   'S',
#   'M',
#   datetime.date(1962, 7, 25),
#   0,
#   None,
#   None,
#   '0',
#   'N',
#   None,
#   None,
#   38962,
#   None,
#   None,
#   "'25411205':5 'albert':4 'carden':1 'pomared':2 'rol':3",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   1955,
#   'DNI'],
#  [146960,
#   'J',
#   114,
#   '20603412461',
#   None,
#   None,
#   'VRV PERNOS & ACEROS E.I.R.L.',
#   'VRV PERNOS & ACEROS E.I.R.L.',
#   'AV. ARGENTINA NRO. 327 INT. Y1-8 (CENTRO COMERCIAL LA BELLOTA PASAJE 1) LIMA - LIMA - LIMA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20603412461',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   2089,
#   "'20603412461':5 'acer':3 'e.i.r.l':4 'pern':2 'vrv':1",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [146965,
#   'J',
#   114,
#   '20603658664',
#   None,
#   None,
#   'HOUSE TOOLS K & M S.A.C.',
#   'HOUSE TOOLS K & M S.A.C.',
#   'JR. HUAROCHIRI NRO. 510 URB. LIMA INDUSTRIAL (C.C PLAZA FERRETERO) LIMA - LIMA - LIMA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20603658664',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20603658664':6 'hous':1 'k':3 'm':4 's.a.c':5 'tools':2",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [146970,
#   'N',
#   113,
#   '46698772',
#   'SANTOS',
#   'LA TORRE',
#   'JACQUELINE FIORELLA',
#   'SANTOS LA TORRE, JACQUELINE FIORELLA',
#   'JR. LUIS MONTERO NRO 2863 URB. ELIO - LIMA - LIMA - LIMA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10466987722',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'46698772':6 'fiorell':5 'jacquelin':4 'sant':1 'torr':3",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [146990,
#   'J',
#   114,
#   '20603279965',
#   None,
#   None,
#   'SOLUCIONES ELECTRIC DYNICELI S.A.C.',
#   'SOLUCIONES ELECTRIC DYNICELI S.A.C.',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20603279965',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20603279965':5 'dyniceli':3 'electric':2 's.a.c':4 'solucion':1",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [147915,
#   'N',
#   113,
#   '10542824',
#   'KADENA',
#   'ODO',
#   'FREDDY',
#   'KADENA ODO, FREDDY',
#   'Av. Carlos Izaguirre 965 LOS OLIVOS -',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10105428249',
#   'N',
#   3694,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10542824':4 'freddy':3 'kaden':1 'odo':2",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [147936,
#   'N',
#   113,
#   '76525844',
#   'CANDIOTE',
#   'CHAVEZ',
#   'MIRIAM ABIGAIL',
#   'CANDIOTE CHAVEZ, MIRIAM ABIGAIL',
#   None,
#   None,
#   'F',
#   datetime.date(2003, 6, 15),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'76525844':5 'abigail':4 'candiot':1 'chavez':2 'miriam':3",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [150392,
#   'N',
#   113,
#   '74074969',
#   'PALOMINO',
#   'HUAMANI',
#   'ALVARO EMERSON',
#   'PALOMINO HUAMANI, ALVARO EMERSON',
#   None,
#   'S',
#   'M',
#   datetime.date(2003, 4, 22),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'74074969':5 'alvar':3 'emerson':4 'huamani':2 'palomin':1",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [150393,
#   'N',
#   113,
#   '73046236',
#   'QUISPE',
#   'TUFINO',
#   'ALEJANDRO',
#   'QUISPE TUFINO, ALEJANDRO',
#   None,
#   'S',
#   'M',
#   datetime.date(2001, 3, 20),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'73046236':4 'alejandr':3 'quisp':1 'tufin':2",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [147944,
#   'J',
#   114,
#   '20552271018',
#   None,
#   None,
#   'VALLY SOCIEDAD ANONIMA CERRADA - VALLY S.A.C',
#   'VALLY SOCIEDAD ANONIMA CERRADA - VALLY S.A.C',
#   'AV. F. ARANCIBIA Nº 679  INT. A -- LIMA - LIMA - RIMAC',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20552271018',
#   'S',
#   3705,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20552271018':7 'anonim':3 'cerr':4 's.a.c':6 'socied':2 'vally':1,5",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [150398,
#   'N',
#   113,
#   '60832527',
#   'CARLOS',
#   'ACOSTA',
#   'VALERIA',
#   'CARLOS ACOSTA, VALERIA',
#   None,
#   'S',
#   'F',
#   datetime.date(2006, 8, 19),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'60832527':4 'acost':2 'carl':1 'valeri':3",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [146956,
#   'J',
#   114,
#   '10744384040',
#   None,
#   None,
#   'CONDO RIOS MARCO ANTONIO',
#   'CONDO RIOS MARCO ANTONIO',
#   '28 DE JULIO  Mz E Lote 02 ABANCAY - ABANCAY-APURIMAC',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10744384040',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10744384040':5 'antoni':4 'cond':1 'marc':3 'rios':2",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [150405,
#   'N',
#   113,
#   '70383959',
#   'RAMOS',
#   'DAVILA',
#   'PRESCILA',
#   'RAMOS DAVILA, PRESCILA',
#   None,
#   'S',
#   'F',
#   None,
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'70383959':4 'davil':2 'prescil':3 'ram':1",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [150416,
#   'J',
#   114,
#   '20608989961',
#   None,
#   None,
#   'BRACSAN S.A.C.',
#   'BRACSAN S.A.C.',
#   'JR. PARURO 1353 URB. BARRIOS ALTOS INT. 214 GALERIA PARURO, LIMA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20608989961',
#   'S',
#   3678,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20608989961':3 'bracs':1 's.a.c':2",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [150418,
#   'J',
#   114,
#   '20549215948',
#   None,
#   None,
#   'IMPORTACIONES EVOLUTIONS MOTORS S.A.C.',
#   'IMPORTACIONES EVOLUTIONS MOTORS S.A.C.',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20549215948',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20549215948':5 'evolutions':2 'import':1 'motors':3 's.a.c':4",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [150424,
#   'J',
#   114,
#   '20602435459',
#   None,
#   None,
#   'MECORLU E.I.R.L.',
#   'MECORLU E.I.R.L.',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20602435459',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20602435459':3 'e.i.r.l':2 'mecorlu':1",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [150427,
#   'J',
#   114,
#   '20510919140',
#   None,
#   None,
#   'ELECTRO FERRETERA D & F E.I.R.L.',
#   'ELECTRO FERRETERA D & F E.I.R.L.',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20510919140',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20510919140':6 'd':3 'e.i.r.l':5 'electr':1 'f':4 'ferreter':2",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [150431,
#   'N',
#   113,
#   '43496105',
#   'BUSTAMANTE',
#   'MOSTAJO',
#   'DANILO EDSON',
#   'BUSTAMANTE MOSTAJO, DANILO EDSON',
#   'AV. CENTRAL Mz. S-1 Lote. 7 LIMA - LIMA - SAN JUAN DE LURIGANCHO',
#   None,
#   'M',
#   None,
#   0,
#   None,
#   None,
#   '10434961055',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'43496105':5 'bustam':1 'danil':3 'edson':4 'mostaj':2",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [162304,
#   'N',
#   113,
#   '21530042',
#   'HUAROTO',
#   'HUACHIN',
#   'AMALIA ESPERANZA',
#   'HUAROTO HUACHIN, AMALIA ESPERANZA',
#   'URB. PLANICIE HUACACHINA F 11 - ICA - ICA - ICA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10215300426',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'21530042':5 'amali':3 'esper':4 'huachin':2 'huarot':1",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [151321,
#   'N',
#   113,
#   '10615941',
#   'NUÑEZ',
#   'LEON',
#   'ELIZABETH YESENIA',
#   'NUÑEZ LEON, ELIZABETH YESENIA',
#   'Jr. Castilla Nro. 855 Int. 101',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   'N',
#   3697,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10615941':5 'elizabeth':3 'leon':2 'nuñez':1 'yeseni':4",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [151323,
#   'J',
#   114,
#   '20537928124',
#   None,
#   None,
#   'COMIDA DEL NORTE S.A.C.',
#   'COMIDA DEL NORTE S.A.C.',
#   'AV. GRAL. GARZON NRO. 1788',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20537928124',
#   'S',
#   3690,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20537928124':5 'com':1 'nort':3 's.a.c':4",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [151324,
#   'N',
#   113,
#   '41226665',
#   'IRRAZABAL',
#   'CHINGEL',
#   'ANTONIA',
#   'IRRAZABAL CHINGEL, ANTONIA',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10412266655',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'41226665':4 'antoni':3 'chingel':2 'irrazabal':1",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [2671,
#   'N',
#   113,
#   '25412783',
#   'PINTO',
#   'PHANG',
#   'AURORA ANGELICA',
#   'PINTO PHANG, AURORA ANGELICA',
#   'LAS HORMIGAS 122 STA. FELICIA',
#   None,
#   'F',
#   datetime.date(1964, 1, 28),
#   1,
#   10469,
#   'FACULTAD DE MEDICINA HUMANA',
#   '0',
#   'N',
#   None,
#   None,
#   38962,
#   None,
#   None,
#   "'25412783':5 'angel':4 'auror':3 'phang':2 'pint':1",
#   None,
#   'DNI',
#   '1',
#   'F01',
#   None,
#   1955,
#   'DNI'],
#  [152868,
#   'N',
#   113,
#   '73124773',
#   'VEGA',
#   'BURGOS',
#   'JOSE EDUARDO ANDRE',
#   'VEGA BURGOS, JOSE EDUARDO ANDRE',
#   'AV. ARGENTINA N° 5260 - PROV. CONST. DEL CALLAO - PROV. CONST. DEL CALLAO - CALLAO',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10731247736',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'73124773':6 'andre':5 'burg':2 'eduard':4 'jos':3 'veg':1",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [150415,
#   'J',
#   114,
#   '20601357691',
#   None,
#   None,
#   'SERVICOMPUTOS.A.C.',
#   'SERVICOMPUTOS.A.C.',
#   'AV. DEL CONTADOR MZA. K LOTE. 18 URB. COVICONT (A UNA CUADRA LOCAL COLEGIO DE CONTADORES) LA LIBERTAD - TRUJILLO - TRUJILLO',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20601357691',
#   'S',
#   3542,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20601357691':2 'servicomputos.a.c':1",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [146895,
#   'N',
#   113,
#   '71759800',
#   'PEDROZA',
#   'HUACCALSAYCO',
#   'SILVIA MARA',
#   'PEDROZA HUACCALSAYCO, SILVIA MARA',
#   None,
#   'S',
#   'F',
#   datetime.date(2000, 6, 3),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'71759800':5 'huaccalsayc':2 'mar':4 'pedroz':1 'silvi':3",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [146896,
#   'N',
#   113,
#   '76194669',
#   'PUMA',
#   'GUEVARA',
#   'JOSSELYN MILAGROS',
#   'PUMA GUEVARA, JOSSELYN MILAGROS',
#   None,
#   'S',
#   'F',
#   datetime.date(2001, 6, 29),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'76194669':5 'guev':2 'josselyn':3 'milagr':4 'pum':1",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [146946,
#   'N',
#   113,
#   '75819222',
#   'RAMOS',
#   'GONZALES',
#   'MAX ANER',
#   'RAMOS GONZALES, MAX ANER',
#   None,
#   None,
#   'M',
#   None,
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'75819222':5 'aner':4 'gonzal':2 'max':3 'ram':1",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [162306,
#   'J',
#   114,
#   '10751895025',
#   None,
#   None,
#   'MALLAUPOMA GRANADOS CRISTOFER ALEXANDER',
#   'MALLAUPOMA GRANADOS CRISTOFER ALEXANDER',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10751895025',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10751895025':5 'alexand':4 'cristof':3 'gran':2 'mallaupom':1",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [97127,
#   'N',
#   113,
#   '44479505',
#   'REAL',
#   'MEJIA',
#   'RENSO JAVIER',
#   'REAL MEJIA, RENSO JAVIER',
#   'MZA. Y LT.. 11 A.H. DANIEL ALCIDES CARRION (CRUCE AV. UNIVERSITARIA Y TOMAS VALLE) LIMA-LIMA-SAN MARTIN DE PORRES',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10444795056',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'44479505':5 'javi':4 'meji':2 'real':1 'rens':3",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [146961,
#   'J',
#   114,
#   '20566186277',
#   None,
#   None,
#   'EQUISEGUR PERU S.A.C.',
#   'EQUISEGUR PERU S.A.C.',
#   'CAL.CESAR VALLEJO NRO. 356 DPTO. 102 URB. PROLONGACION BENAVIDESLIMA - LIMA - SANTIAGO DE SURCO',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20566186277',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20566186277':4 'equisegur':1 'peru':2 's.a.c':3",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [146865,
#   'N',
#   113,
#   '07241747',
#   'VARGAS',
#   'ARCE',
#   'TRINATORIO DARIO',
#   'VARGAS ARCE, TRINATORIO DARIO',
#   'JR. SORIANO INFANTE NRO. 15 INT. 01 - HUARAZ - ANCASH',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10072417475',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'07241747':5 'arce':2 'dari':4 'trinatori':3 'varg':1",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [132922,
#   'N',
#   113,
#   '06705213',
#   'SANCHEZ',
#   'RODRIGUEZ',
#   'JUANA PRESENTACIÓN',
#   'SANCHEZ RODRIGUEZ, JUANA PRESENTACIÓN',
#   'JR. AMÉZAGA N°375- LIMA ',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10067052132',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'06705213':5 'juan':3 'present':4 'rodriguez':2 'sanchez':1",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [146962,
#   'J',
#   114,
#   '10726839056',
#   None,
#   None,
#   'BERROSPI ZAPATA ARIHASCHNA JOYCE',
#   'BERROSPI ZAPATA ARIHASCHNA JOYCE',
#   'CAL. 5 MZ P1 LOTE 8 URB. LOS PILARES ADUANEROS PROV. CONST. DEL CALLAO PROV. CONST. DEL CALLAO - CALLAO',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10726839056',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10726839056':5 'arihaschn':3 'berrospi':1 'joyc':4 'zapat':2",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [146963,
#   'N',
#   113,
#   '46740476',
#   'GAVINO',
#   'CRISPIN',
#   'ZAIDA NATIVA',
#   'GAVINO CRISPIN, ZAIDA NATIVA',
#   'CAL. VENTURA MONJARAS 292 URB. LOS TUMIS CARABAYLLO LIMA - LIMA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10467404763',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'46740476':5 'crispin':2 'gavin':1 'nativ':4 'zaid':3",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [146966,
#   'J',
#   114,
#   '10700553693',
#   None,
#   None,
#   'RONDAN GARCIA HEYDY BRILLIT',
#   'RONDAN GARCIA HEYDY BRILLIT',
#   'JR. HUAROCHIRI CC PLAZA FERRE 518 URB. LIMA INDUSTRIAL INT. 1015',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10700553693',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10700553693':5 'brillit':4 'garci':2 'heydy':3 'rond':1",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [146967,
#   'J',
#   114,
#   '10734732872',
#   None,
#   None,
#   'BARDALEZ CASTILLO ROSA ANGELICA',
#   'BARDALEZ CASTILLO ROSA ANGELICA',
#   'JR. CUZCO NRO. 459A - LIMA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10734732872',
#   'N',
#   3678,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10734732872':5 'angel':4 'bardalez':1 'castill':2 'ros':3",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [147916,
#   'N',
#   113,
#   '71455338',
#   'BONIFÁZ',
#   'VARGAS',
#   'GERARDO VIDAL LUIS',
#   'BONIFÁZ VARGAS, GERARDO VIDAL LUIS',
#   None,
#   None,
#   'M',
#   datetime.date(2002, 11, 12),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'71455338':6 'bonifaz':1 'gerard':3 'luis':5 'varg':2 'vidal':4",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [2529,
#   'N',
#   113,
#   '25413436',
#   'RODRIGUEZ',
#   'MICHUY',
#   'DORA NANCY',
#   'RODRIGUEZ MICHUY, DORA NANCY',
#   'AV. PACASMAYO 333 DPTO.12 CIUDAD SAT. STA. ROSA - CALLAO',
#   'S',
#   'F',
#   datetime.date(1962, 1, 26),
#   1,
#   10469,
#   'FACULTAD DE MEDICINA HUMANA',
#   '0',
#   'N',
#   None,
#   None,
#   38962,
#   None,
#   None,
#   "'25413436':5 'dor':3 'michuy':2 'nancy':4 'rodriguez':1",
#   None,
#   'DNI',
#   '1',
#   'F01',
#   None,
#   1955,
#   'DNI'],
#  [152869,
#   'J',
#   114,
#   '20611448245',
#   None,
#   None,
#   'DECISTE PUBLICIDAD MARKETING E.I.R.L.',
#   'DECISTE PUBLICIDAD MARKETING E.I.R.L.',
#   'AV. BOLIVIA 148 CERCADO DE LIMA INT. 2046',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20611448245',
#   'S',
#   3678,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20611448245':5 'dec':1 'e.i.r.l':4 'marketing':3 'public':2",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [146980,
#   'J',
#   114,
#   '20550633460',
#   None,
#   None,
#   'PACKAGING BOXES SAC',
#   'PACKAGING BOXES SAC',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20550633460',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20550633460':4 'box':2 'packaging':1 'sac':3",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [146950,
#   'N',
#   113,
#   '43074028',
#   'CUEVA',
#   'SEMINARIO',
#   'AMBAR LIBBETT',
#   'CUEVA SEMINARIO, AMBAR LIBBETT',
#   'Av. Tupac Amaru Mz :A Lte: 14 Leticia - Rímac',
#   None,
#   'F',
#   None,
#   0,
#   None,
#   None,
#   '10430740283',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'43074028':5 'ambar':3 'cuev':1 'libbett':4 'seminari':2",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [251,
#   'N',
#   113,
#   '07170873',
#   'CUAREZ',
#   'LLALLIRE',
#   'MARINO',
#   'CUAREZ LLALLIRE, MARINO',
#   'SANTA MARITZA 170 PALAO - SAN MARTIN DE PORRES',
#   None,
#   'M',
#   datetime.date(1953, 1, 25),
#   0,
#   None,
#   None,
#   '10071708735',
#   'N',
#   None,
#   None,
#   None,
#   None,
#   None,
#   "'07170873':4 'cuarez':1 'llallir':2 'marin':3",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   1955,
#   'DNI'],
#  [146982,
#   'N',
#   113,
#   '75496994',
#   'ESPINOZA',
#   'BECERRA',
#   'ANGELICA VICTORIA',
#   'ESPINOZA BECERRA, ANGELICA VICTORIA',
#   'PJ. 7 MZ.N LT.18 URB. LEONCIO PRADO RIMAC LIMA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10754969941',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'75496994':5 'angel':3 'becerr':2 'espinoz':1 'victori':4",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [146987,
#   'N',
#   113,
#   '72671468',
#   'HUAMAN',
#   'RAMIREZ',
#   'ROLY ROBERT',
#   'HUAMAN RAMIREZ, ROLY ROBERT',
#   None,
#   None,
#   'M',
#   None,
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'72671468':5 'huam':1 'ramirez':2 'robert':4 'roly':3",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [146972,
#   'J',
#   114,
#   '10490605661',
#   None,
#   None,
#   'MELENDEZ CHUQUINO ROSMERY KATHERIN',
#   'MELENDEZ CHUQUINO ROSMERY KATHERIN',
#   'JR. CAMANA 1152 247 CERCADO DE LIMA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10490605661',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10490605661':5 'chuquin':2 'katherin':4 'melendez':1 'rosmery':3",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [146973,
#   'J',
#   114,
#   '20600155874',
#   None,
#   None,
#   'SOCIEDAD GLOBALIZADA DE CONSULTORES S.A.C.',
#   'SOCIEDAD GLOBALIZADA DE CONSULTORES S.A.C.',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20600155874',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20600155874':6 'consultor':4 'globaliz':2 's.a.c':5 'socied':1",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [146975,
#   'J',
#   114,
#   '20606174510',
#   None,
#   None,
#   'ARENAS INGENIERIA AUTOMOTRIZ E.I.R.L',
#   'ARENAS INGENIERIA AUTOMOTRIZ E.I.R.L',
#   'A.H PANDO ET. NUEVE MZA.A LOTE. 21 SAN MIGUEL - LIMA - LIMA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20606174510',
#   'S',
#   3713,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20606174510':5 'aren':1 'automotriz':3 'e.i.r.l':4 'ingenieri':2",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [146976,
#   'N',
#   113,
#   '46164256',
#   'SAAVEDRA',
#   'TORRES',
#   'FIORELLA ELEONORA',
#   'SAAVEDRA TORRES, FIORELLA ELEONORA',
#   'JR. PACHITEA N° 730 URB. CERCADO DE PUCALLPA - CALLERIA - CORONEL PORTILLO - UCAYALI',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10461642565',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'46164256':5 'eleonor':4 'fiorell':3 'saavedr':1 'torr':2",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [146978,
#   'N',
#   113,
#   '76419421',
#   'OCHOA',
#   'PEREZ',
#   'DENILZON',
#   'OCHOA PEREZ, DENILZON',
#   'CAS. MUYUY II ZONA FERNANDO LORES - MAYNAS - LORETO',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10764194212',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'76419421':4 'denilzon':3 'ocho':1 'perez':2",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [146834,
#   'J',
#   114,
#   '10772844447',
#   None,
#   None,
#   'ALEJANDRO ZAIR HUANAQUIRI YALICO',
#   'ALEJANDRO ZAIR HUANAQUIRI YALICO',
#   'A.H. PANDO CAL. LOS NARANJALES - MZ. N LOTE 12 - SAN MIGUEL - LIMA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10772844447',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10772844447':5 'alejandr':1 'huanaquiri':3 'yalic':4 'zair':2",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [146986,
#   'N',
#   113,
#   '76605789',
#   'FIGUEROA',
#   'CURO',
#   'JUAN DIEGO',
#   'FIGUEROA CURO, JUAN DIEGO',
#   None,
#   None,
#   'M',
#   None,
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'76605789':5 'cur':2 'dieg':4 'figuero':1 'juan':3",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [146989,
#   'J',
#   114,
#   '10079738749',
#   None,
#   None,
#   'TIZA SOLORZANO SONIA MARIBEL',
#   'TIZA SOLORZANO SONIA MARIBEL',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10079738749',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10079738749':5 'maribel':4 'solorzan':2 'soni':3 'tiz':1",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [56832,
#   'J',
#   114,
#   '20259940860',
#   None,
#   None,
#   'QUICKPACK PERU S A C',
#   'QUICKPACK PERU S A C',
#   'JR. SALAVERRY NRO. 1485 (ALTURA CUADRA 44 REPUBLICA PANAMA) LIMA - LIMA - SURQUILLO',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20259940860',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20259940860':6 'c':5 'peru':2 'quickpack':1 's':3",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [146964,
#   'J',
#   114,
#   '10421805810',
#   None,
#   None,
#   'POMALAZA ANGULO JESSICA ZENAIDA',
#   'POMALAZA ANGULO JESSICA ZENAIDA',
#   'A.H. LAS ESTERAS II - Mz. BLt. 39 - ANCON- LIMA.',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10421805810',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10421805810':5 'angul':2 'jessic':3 'pomalaz':1 'zen':4",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [146984,
#   'N',
#   113,
#   '42120604',
#   'MACEDO',
#   'CARDENAS',
#   'RONALD',
#   'MACEDO CARDENAS, RONALD',
#   'JR. VIRGEN DE FATIMA  MZ. O LOTE 11 A.H. VIRGEN DE LA PURISIMA - CALLERIA - CORONEL PORTILLO - UCAYALI',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10421206045',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'42120604':4 'carden':2 'maced':1 'ronald':3",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [146983,
#   'N',
#   113,
#   '47515230',
#   'RODRIGUEZ',
#   'VELASQUEZ',
#   'GROVER',
#   'RODRIGUEZ VELASQUEZ, GROVER',
#   'JR. AGUAYTIA NRO167 - CALLERIA - CORONEL PORTILLO - UCAYALI',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10475152307',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'47515230':4 'grov':3 'rodriguez':1 'velasquez':2",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [146974,
#   'J',
#   114,
#   '10417710553',
#   None,
#   None,
#   'NOEL SEMER ESPINOZA NAVARRO',
#   'NOEL SEMER ESPINOZA NAVARRO',
#   'JR. LUIS GIRIBALDI N° 515, INT.223-URB. EL PORVENIR-LA VICTORIA-LIMA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10417710553',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10417710553':5 'espinoz':3 'navarr':4 'noel':1 'sem':2",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [146985,
#   'J',
#   114,
#   '20513121041',
#   None,
#   None,
#   'RP INTERNATIONAL S.A.C',
#   'RP INTERNATIONAL S.A.C',
#   'CAL.EL BOULEVARD NRO. 141 INT. 201 URB. EL POLO HUNT (URB. EL POLO) LIMA - LIMA - SANTIAGO DE SURCO',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20513121041',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20513121041':4 'international':2 'rp':1 's.a.c':3",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [105414,
#   'N',
#   113,
#   '71608771',
#   'CHIPA',
#   'QUISPE',
#   'PAOLA ESPERANZA',
#   'CHIPA QUISPE, PAOLA ESPERANZA',
#   'URB. PROLONG.BENAVIDES Mz. B6 Lt. 24 - LIMA/LIMA/SANTIAGO DE SURCO',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10716087714',
#   'N',
#   3717,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'71608771':5 'chip':1 'esper':4 'paol':3 'quisp':2",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [146921,
#   'N',
#   113,
#   '43004231',
#   'MADRID',
#   'VALVERDE',
#   'CARLOS JAVIER',
#   'MADRID VALVERDE, CARLOS JAVIER',
#   'JOSE PARDO 1035 - MIRAFLORES',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10430042314',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'43004231':5 'carl':3 'javi':4 'madr':1 'valverd':2",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [162307,
#   'N',
#   113,
#   '08695113',
#   'MARIÑOS',
#   'GONZALES',
#   'ANGELINA ELISA',
#   'MARIÑOS GONZALES, ANGELINA ELISA',
#   'PASAJE LA LIBERTAD 667 JR. CANETE - COMAS - LIMA - LIMA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10086951130',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'08695113':5 'angelin':3 'elis':4 'gonzal':2 'mariñ':1",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [147919,
#   'N',
#   113,
#   '76953070',
#   'CABANILLAS',
#   'DIAZ',
#   'ANSHELO DANTOL',
#   'CABANILLAS DIAZ, ANSHELO DANTOL',
#   None,
#   None,
#   'M',
#   datetime.date(2002, 9, 3),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'76953070':5 'anshel':3 'cabanill':1 'dantol':4 'diaz':2",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [146954,
#   'J',
#   114,
#   '10413844296',
#   None,
#   None,
#   'SALDAÑA VIOLETA JOSE LUIS',
#   'SALDAÑA VIOLETA JOSE LUIS',
#   'AV PROCERES 7811 - URB.1RA DE PRO - LOS OLIVOS/ LIMA/ LIMA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10413844296',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10413844296':5 'jos':3 'luis':4 'saldañ':1 'violet':2",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [146971,
#   'J',
#   114,
#   '10481268015',
#   None,
#   None,
#   'HUAYANEY COCHACHIN DAVID LUIS',
#   'HUAYANEY COCHACHIN DAVID LUIS',
#   'CAL. LA FRONTERA MZA. D INT. 2A LOTE 58 URB. INDUSTRIAL LIMA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10481268015',
#   'N',
#   3689,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10481268015':5 'cochachin':2 'dav':3 'huayaney':1 'luis':4",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [51016,
#   'J',
#   114,
#   '20508243490',
#   None,
#   None,
#   'MULTISERVICIOS INFORMATICOS S.A.C.',
#   'MULTISERVICIOS INFORMATICOS S.A.C.',
#   'CAL.LAS CALENDULAS NRO. 688 COO. LAS FLORES LIMA - LIMA - SAN JUAN DE LURIGANCHO',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20508243490',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20508243490':4 'informat':2 'multiservici':1 's.a.c':3",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [146977,
#   'N',
#   113,
#   '25744719',
#   'BONILLA',
#   'FOINQUINOS',
#   'LUIS RAFAEL',
#   'BONILLA FOINQUINOS, LUIS RAFAEL',
#   ' CAL. FEDERICO NOGUERA 191 - URB. STELLA MARIS - PROV.CONSTITUCIONAL DEL CALLAO/PROV.CONSTITUCIONAL DEL CALLAO/BELLAVISTA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10257447192',
#   'N',
#   3045,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'25744719':5 'bonill':1 'foinquin':2 'luis':3 'rafael':4",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [146988,
#   'N',
#   113,
#   '75603392',
#   'HUAMAN',
#   'VELARDE',
#   'MERY ALLISSON',
#   'HUAMAN VELARDE, MERY ALLISSON',
#   None,
#   None,
#   'F',
#   None,
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'75603392':5 'allisson':4 'huam':1 'mery':3 'velard':2",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [147937,
#   'N',
#   113,
#   '76368016',
#   'CARBAJAL',
#   'POMAHUALLCA',
#   'NICOHOL YASMIN',
#   'CARBAJAL POMAHUALLCA, NICOHOL YASMIN',
#   None,
#   None,
#   'F',
#   datetime.date(2004, 2, 15),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'76368016':5 'carbajal':1 'nicohol':3 'pomahuallc':2 'yasmin':4",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [147008,
#   'N',
#   113,
#   '76826158',
#   'BEDOYA',
#   'RONCEROS',
#   'ELUSALEN VERONICA',
#   'BEDOYA RONCEROS, ELUSALEN VERONICA',
#   'MZ.D LT.3 ASENT.H. DE LA TORRE CALLAO - PROV. CONST. DEL CALLAO',
#   None,
#   'F',
#   None,
#   0,
#   None,
#   None,
#   '10768261585',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'76826158':5 'bedoy':1 'elusal':3 'roncer':2 'veron':4",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [62157,
#   'J',
#   114,
#   '10067052132',
#   None,
#   None,
#   'SANCHEZ RODRIGUEZ JUANA PRESENTACION',
#   'SANCHEZ RODRIGUEZ JUANA PRESENTACION',
#   'JR. AMÉZAGA N°375- LIMA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10067052132',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10067052132':5 'juan':3 'presentacion':4 'rodriguez':2 'sanchez':1",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [146992,
#   'N',
#   113,
#   '06261286',
#   'ORTIZ',
#   'BENITES',
#   'MIGUEL HUMBERTO',
#   'ORTIZ BENITES, MIGUEL HUMBERTO',
#   'JR. MARACIBO N°2065 - URB PERU ETP 2 - SAN MARTIN DE PORRES - LIMA - LIMA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10062612865',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'06261286':5 'benit':2 'humbert':4 'miguel':3 'ortiz':1",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [146899,
#   'N',
#   113,
#   '75400123',
#   'RAMIREZ',
#   'MINCHAN',
#   'BRYAM GLEND',
#   'RAMIREZ MINCHAN, BRYAM GLEND',
#   None,
#   'S',
#   'M',
#   datetime.date(2002, 6, 6),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'75400123':5 'bryam':3 'glend':4 'minch':2 'ramirez':1",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [2528,
#   'N',
#   113,
#   '25414792',
#   'SALDAÑA',
#   'VILLAVICENCIO',
#   'AMELIA',
#   'SALDAÑA VILLAVICENCIO, AMELIA',
#   'JR.ANDALUCIA 834 DPTO 501',
#   'S',
#   'F',
#   datetime.date(1953, 4, 12),
#   0,
#   None,
#   None,
#   '0',
#   'N',
#   None,
#   None,
#   38962,
#   None,
#   None,
#   "'25414792':4 'ameli':3 'saldañ':1 'villavicenci':2",
#   None,
#   'DNI',
#   '1',
#   None,
#   None,
#   1955,
#   'DNI'],
#  [150399,
#   'N',
#   113,
#   '71407475',
#   'ALLCARIMA',
#   'LIBIA',
#   'DORIS MIREYA',
#   'ALLCARIMA LIBIA, DORIS MIREYA',
#   None,
#   'S',
#   'F',
#   datetime.date(1997, 1, 20),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'71407475':5 'allcarim':1 'doris':3 'libi':2 'mirey':4",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [150419,
#   'J',
#   114,
#   '10724125846',
#   None,
#   None,
#   'HILARIO ESTEBAN LIZBETH ELSA',
#   'HILARIO ESTEBAN LIZBETH ELSA',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10724125846',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10724125846':5 'elsa':4 'esteb':2 'hilari':1 'lizbeth':3",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [150421,
#   'J',
#   114,
#   '20608965573',
#   None,
#   None,
#   'INVERSIONES JAVIER ALDAIR SAC',
#   'INVERSIONES JAVIER ALDAIR SAC',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20608965573',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20608965573':5 'alda':3 'inversion':1 'javi':2 'sac':4",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [151328,
#   'J',
#   114,
#   '20601119405',
#   None,
#   None,
#   'LV CONSULTORIA Y SERVICIOS GENERALES SOCIEDAD ANONIMA CERRADA',
#   'LV CONSULTORIA Y SERVICIOS GENERALES SOCIEDAD ANONIMA CERRADA',
#   'AV. OCOPILLA NRO. SN (S68100971-N475-1CDRA CAPILLA OCOPILLA) JUNIN - HUANCAYO - HUANCAYO',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20601119405',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20601119405':9 'anonim':7 'cerr':8 'consultori':2 'general':5 'lv':1 'servici':4 'socied':6",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [151329,
#   'J',
#   114,
#   '20600167791',
#   None,
#   None,
#   'CORPORACION GN WINER S.A.C.',
#   'CORPORACION GN WINER S.A.C.',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20600167791',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20600167791':5 'corporacion':1 'gn':2 's.a.c':4 'win':3",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [113938,
#   'N',
#   113,
#   '70057629',
#   'MARCHENA',
#   'SARMIENTO',
#   'REYMEGAN ABIGAIL',
#   'MARCHENA SARMIENTO, REYMEGAN ABIGAIL',
#   'MCAL MILLER N° 949 - LIMA - LIMA - JESUS MARIA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10700576294',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'70057629':5 'abigail':4 'marchen':1 'reymeg':3 'sarmient':2",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [9223,
#   'N',
#   113,
#   '25420840',
#   'HUABLOCHO',
#   'PEREZ',
#   'TEOFILO MATIAS',
#   'HUABLOCHO PEREZ, TEOFILO MATIAS',
#   'CL AYACUCHO 747 LA PERLA - CALLAO',
#   'C',
#   'M',
#   datetime.date(1955, 3, 10),
#   1,
#   11259,
#   'FACULTAD DE INGENIERÍA ELECTRÓNICA Y ELÉCTRICA',
#   '0',
#   'N',
#   None,
#   None,
#   38962,
#   None,
#   None,
#   "'25420840':5 'huabloch':1 'mati':4 'perez':2 'teofil':3",
#   None,
#   'DNI',
#   '1',
# ...
#   1955,
#   'PERÚ',
#   None,
#   "'20600890418':4 'bl':1 'comput':2 's.a.c':3",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [148138,
#   'N',
#   21092,
#   '31042300',
#   'VERA',
#   'PINTO',
#   'ABDEL',
#   'VERA PINTO, ABDEL',
#   'AV. BOLOGNESI N° 941 - DPTO N° 201 - URB. SAN IGNACIO - BARRANCO - LIMA - LIMA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10310423004',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'31042300':4 'abdel':3 'pint':2 'ver':1",
#   '0',
#   'PROV',
#   '1',
#   None,
#   None,
#   None,
#   'PROV'],
#  [128372,
#   'N',
#   113,
#   '47078780',
#   'GARCIA',
#   'ASPILCUETA',
#   'JONATHAN',
#   'GARCIA ASPILCUETA, JONATHAN',
#   'CAL. 37 MZA. P4 LOTE. 61 URB. PUERTA DE PRO LIMA - LIMA - SAN MARTIN DE PORRES.',
#   None,
#   'M',
#   None,
#   0,
#   None,
#   None,
#   '10470787801',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'47078780':4 'aspilcuet':2 'garci':1 'jonath':3",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [148145,
#   'N',
#   113,
#   '72252001',
#   'MORI',
#   'HUERTA',
#   'DIANA GRISEL',
#   'MORI HUERTA, DIANA GRISEL',
#   None,
#   'S',
#   'F',
#   datetime.date(2000, 7, 31),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'72252001':5 'dian':3 'grisel':4 'huert':2 'mori':1",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [148146,
#   'N',
#   113,
#   '72767909',
#   'NAVARRO',
#   'VILLARREAL',
#   'KELVIN JOSE',
#   'NAVARRO VILLARREAL, KELVIN JOSE',
#   None,
#   'S',
#   'M',
#   datetime.date(2000, 10, 4),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'72767909':5 'jos':4 'kelvin':3 'navarr':1 'villarreal':2",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [148157,
#   'N',
#   113,
#   '73615027',
#   'ORTIZ',
#   'PEREZ',
#   'BRAYAN JUAN',
#   'ORTIZ PEREZ, BRAYAN JUAN',
#   None,
#   'S',
#   'M',
#   datetime.date(1999, 10, 21),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'73615027':5 'bray':3 'juan':4 'ortiz':1 'perez':2",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [148161,
#   'N',
#   113,
#   '47877481',
#   'PARI',
#   'HUAMAN',
#   'KETTY JULISSA',
#   'PARI HUAMAN, KETTY JULISSA',
#   None,
#   'S',
#   'F',
#   datetime.date(1993, 8, 24),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'47877481':5 'huam':2 'juliss':4 'ketty':3 'pari':1",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [151372,
#   'J',
#   114,
#   '10422001536',
#   None,
#   None,
#   'FERNANDEZ DE LA CRUZ ALEJANDRO JAVIER',
#   'FERNANDEZ DE LA CRUZ ALEJANDRO JAVIER',
#   'JR LOS CHASQUIS 709 URB. ZARATE SAN JUAN DE LURIGANCHO-LIMA-LIMA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10422001536',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10422001536':7 'alejandr':5 'cruz':4 'fernandez':1 'javi':6",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [148130,
#   'N',
#   113,
#   '72389787',
#   'MAYHUASCA',
#   'SCHAUS',
#   'LEIDY MARIELLA',
#   'MAYHUASCA SCHAUS, LEIDY MARIELLA',
#   'URB. VILLA GENOVA MZ E LT. 11 SAN MARTIN DE PORRES LIMA ',
#   'S',
#   'F',
#   datetime.date(2000, 9, 14),
#   0,
#   None,
#   None,
#   '10723897870',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'72389787':5 'leidy':3 'mariell':4 'mayhuasc':1 'schaus':2",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [133517,
#   'N',
#   113,
#   '09796915',
#   'FARROÑAY',
#   'CHAFLOQUE',
#   'LUCILA DEL ROCIO',
#   'FARROÑAY CHAFLOQUE, LUCILA DEL ROCIO',
#   'JIRON PEREZ DE TUDELA 2610, CERCADO DE LIMA, LIMA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10097969154',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'09796915':6 'chafloqu':2 'farroñay':1 'lucil':3 'roci':5",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [156852,
#   'N',
#   113,
#   '25606357',
#   'BAZALAR',
#   'BOULANGGER',
#   'ANA CECILIA',
#   'BAZALAR BOULANGGER, ANA CECILIA',
#   None,
#   ' ',
#   'F',
#   datetime.date(1900, 1, 4),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   None,
#   None,
#   None,
#   "'25606357':5 'ana':3 'bazal':1 'boulangg':2 'cecili':4",
#   None,
#   'DNI',
#   '9',
#   None,
#   None,
#   1955,
#   'DNI'],
#  [6239,
#   'N',
#   113,
#   '25606396',
#   'FLORES',
#   'CENTURION',
#   'ROSARIO ISABEL',
#   'FLORES CENTURION, ROSARIO ISABEL',
#   'JR.NICOLAS DE PIEROLA 364 I-10                              ',
#   None,
#   'F',
#   datetime.date(1956, 5, 28),
#   1,
#   10778,
#   'FACULTAD DE QUIMICA E ING. QUIMICA',
#   '',
#   'N',
#   None,
#   None,
#   38962,
#   None,
#   None,
#   "'25606396':5 'centurion':2 'flor':1 'isabel':4 'rosari':3",
#   None,
#   'DNI',
#   '1',
#   'F07',
#   None,
#   1955,
#   'DNI'],
#  [4312,
#   'N',
#   113,
#   '25606829',
#   'CASAVERDE',
#   'RIOS',
#   'ALBERTO JORGE',
#   'CASAVERDE RIOS, ALBERTO JORGE',
#   '',
#   'C',
#   'M',
#   datetime.date(1961, 11, 8),
#   1,
#   10557,
#   'FACULTAD DE DERECHO Y CIENCIA POLÍTICA',
#   '10256068295',
#   'N',
#   None,
#   None,
#   38962,
#   None,
#   None,
#   "'25606829':5 'albert':3 'casaverd':1 'jorg':4 'rios':2",
#   None,
#   'DNI',
#   '1',
#   'F02',
#   None,
#   1955,
#   'DNI'],
#  [156853,
#   'N',
#   113,
#   '25607444',
#   'LORO',
#   'CHERO',
#   'LUIS MELCHOR',
#   'LORO CHERO, LUIS MELCHOR',
#   None,
#   'C',
#   'M',
#   datetime.date(1963, 2, 8),
#   0,
#   None,
#   None,
#   '0',
#   'N',
#   None,
#   None,
#   38962,
#   None,
#   None,
#   "'25607444':5 'cher':2 'lor':1 'luis':3 'melchor':4",
#   None,
#   'DNI',
#   '1',
#   None,
#   None,
#   1955,
#   'DNI'],
#  [66580,
#   'J',
#   114,
#   '20107903951',
#   None,
#   None,
#   'TRADING SERVICE M & A S.R.LTDA',
#   'TRADING SERVICE M & A S.R.LTDA',
#   'JR. CAMANA NRO. 1043 DPTO. 105 INT. A (ALTURA PLAZA FRANCIA) LIMA - LIMA - LIMA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20107903951',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20107903951':6 'm':3 's.r.ltda':5 'servic':2 'trading':1",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [148100,
#   'N',
#   113,
#   '75984652',
#   'MALLCO',
#   'LAURENTE',
#   'FRANS ANDRE',
#   'MALLCO LAURENTE, FRANS ANDRE',
#   None,
#   None,
#   'M',
#   datetime.date(2002, 10, 27),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'75984652':5 'andre':4 'frans':3 'laurent':2 'mallc':1",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [148124,
#   'N',
#   113,
#   '72405906',
#   'MARQUEZ',
#   'TAMAYO',
#   'ALLISON JAZMIN',
#   'MARQUEZ TAMAYO, ALLISON JAZMIN',
#   None,
#   'S',
#   'F',
#   datetime.date(2003, 5, 28),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'72405906':5 'allison':3 'jazmin':4 'marquez':1 'tamay':2",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [148125,
#   'N',
#   113,
#   '48012336',
#   'FLORES',
#   'CLEMENTE',
#   'DEMETRIO GUILLERMO',
#   'FLORES CLEMENTE, DEMETRIO GUILLERMO',
#   'MZA. B1 LOTE 11 APV.POBLADORES LA ARBOLADA LIMA-LIMA-COMAS',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10480123366',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'48012336':5 'clement':2 'demetri':3 'flor':1 'guillerm':4",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [148148,
#   'N',
#   113,
#   '72405941',
#   'NEYRA',
#   'DE LA CRUZ',
#   'KARLA ISABEL',
#   'NEYRA DE LA CRUZ, KARLA ISABEL',
#   None,
#   'S',
#   'F',
#   datetime.date(2001, 7, 22),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'72405941':7 'cruz':4 'isabel':6 'karl':5 'neyr':1",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [148158,
#   'N',
#   113,
#   '72481672',
#   'PALACIOS',
#   'PRIETO',
#   'CRISTHIAN ANDRÉ',
#   'PALACIOS PRIETO, CRISTHIAN ANDRÉ',
#   None,
#   'S',
#   'M',
#   datetime.date(1998, 4, 6),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'72481672':5 'andre':4 'cristhi':3 'palaci':1 'priet':2",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [148162,
#   'N',
#   113,
#   '70776384',
#   'PARIAN',
#   'GARCIA',
#   'RAUL ELBER JOHAN',
#   'PARIAN GARCIA, RAUL ELBER JOHAN',
#   None,
#   'S',
#   'M',
#   datetime.date(2002, 1, 22),
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'70776384':6 'elber':4 'garci':2 'joh':5 'pari':1 'raul':3",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [80924,
#   'J',
#   114,
#   '10094496514',
#   None,
#   None,
#   'PAREDES PEREZ ANA MARIA DEL CARMEN',
#   'PAREDES PEREZ ANA MARIA DEL CARMEN',
#   'JR. LOS CHASQUIS Nº 7136  URB TREBOL - LOS OLIVOS',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10094496514',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10094496514':7 'ana':3 'carm':6 'mari':4 'pared':1 'perez':2",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [148223,
#   'N',
#   113,
#   '00075987',
#   'OPERADOR',
#   'LOGISTICO I',
#   'FACULTAD DE CIENCIAS SOCIALES',
#   'OPERADOR LOGISTICO I, FACULTAD DE CIENCIAS SOCIALES',
#   None,
#   None,
#   'M',
#   None,
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'00075987':8 'cienci':6 'facult':4 'i':3 'logist':2 'oper':1 'social':7",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [150498,
#   'N',
#   113,
#   '72691104',
#   'BAILON',
#   'VENTO',
#   'ANDRES SEBASTIAN',
#   'BAILON VENTO, ANDRES SEBASTIAN',
#   None,
#   'S',
#   'M',
#   None,
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'72691104':5 'andres':3 'bailon':1 'sebasti':4 'vent':2",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [148230,
#   'J',
#   114,
#   '10102245500',
#   None,
#   None,
#   'VERA RIMOND MARIA ROXANNA',
#   'VERA RIMOND MARIA ROXANNA',
#   'AV. LOS OLIVOS MZ. E1 LT. 03 LIMA-LOS OLIVOS',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10102245500',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10102245500':5 'mari':3 'rimond':2 'roxann':4 'ver':1",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [150502,
#   'N',
#   113,
#   '71711758',
#   'CHIARA',
#   'HUAMANI',
#   'JAMIR NICOLAS',
#   'CHIARA HUAMANI, JAMIR NICOLAS',
#   None,
#   'S',
#   'M',
#   None,
#   0,
#   None,
#   None,
#   None,
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'71711758':5 'chi':1 'huamani':2 'jam':3 'nicol':4",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [148233,
#   'J',
#   114,
#   '10703423375',
#   None,
#   None,
#   'CARHUAZ ARMESTAR ELMER EDSON',
#   'CARHUAZ ARMESTAR ELMER EDSON',
#   'JR.RIO CHICAMA MZ.Z LT.09 URB.VILLA DEL NORTE  LIMA  LIMA LOS OLIVOS',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10703423375',
#   'N',
#   3694,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10703423375':5 'armest':2 'carhuaz':1 'edson':4 'elmer':3",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [150507,
#   'J',
#   114,
#   '10098227518',
#   None,
#   None,
#   'ARTESANIA JORGE',
#   'ARTESANIA JORGE',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10098227518',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10098227518':3 'artesani':1 'jorg':2",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [148321,
#   'J',
#   114,
#   '20610003541',
#   None,
#   None,
#   'DISTRIBUCIONES GENERALES ROIS E.I.R.L.',
#   'DISTRIBUCIONES GENERALES ROIS E.I.R.L.',
#   'CAL.CENTRO ESCOLAR NRO. 358 DPTO. A URB. BARRIOS ALTOS LIMA - LIMA - LIMA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20610003541',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20610003541':5 'distribu':1 'e.i.r.l':4 'general':2 'rois':3",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [3776,
#   'N',
#   113,
#   '25607630',
#   'SCHENONE',
#   'DE MARQUINA',
#   'MARTA IRMA',
#   'SCHENONE DE MARQUINA, MARTA IRMA',
#   'JULIO C. TELLO 343 URB SAN JOS                              ',
#   None,
#   'F',
#   datetime.date(1936, 2, 23),
#   1,
#   10469,
#   'FACULTAD DE MEDICINA HUMANA',
#   '0',
#   'N',
#   None,
#   None,
#   38962,
#   None,
#   None,
#   "'25607630':6 'irma':5 'marquin':3 'mart':4 'schenon':1",
#   None,
#   'DNI',
#   '1',
#   'F01',
#   None,
#   1955,
#   'DNI'],
#  [148323,
#   'J',
#   114,
#   '10464402603',
#   None,
#   None,
#   'CHAMBA CHAMBERGO MIGUEL ANGEL',
#   'CHAMBA CHAMBERGO MIGUEL ANGEL',
#   'Av. German Aguirre Ugarte 1098 Urb. El Rosario San Martín de Porres',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10464402603',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10464402603':5 'angel':4 'chamb':1 'chamberg':2 'miguel':3",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [148324,
#   'N',
#   113,
#   '73713658',
#   'MENDOZA',
#   'ZAPATA',
#   'EDUARDO MANUEL',
#   'MENDOZA ZAPATA, EDUARDO MANUEL',
#   'Calle Las Hiedras  100 Urb. El Ermitaño Independencia',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10737136588',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'73713658':5 'eduard':3 'manuel':4 'mendoz':1 'zapat':2",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [148325,
#   'J',
#   114,
#   '20607071749',
#   None,
#   None,
#   'BLUE ROYAL  E.I.R.L.',
#   'BLUE ROYAL  E.I.R.L.',
#   None,
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20607071749',
#   'S',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20607071749':4 'blu':1 'e.i.r.l':3 'royal':2",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [148330,
#   'N',
#   113,
#   '25759127',
#   'VALENCIA',
#   'MIRANDA',
#   'MARIA VICTORIA',
#   'VALENCIA MIRANDA, MARIA VICTORIA',
#   'Av. Alfredo Palacios ME Lte. 8 Urb. el Carmen',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   None,
#   'N',
#   2081,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'25759127':5 'mari':3 'mirand':2 'valenci':1 'victori':4",
#   '0',
#   'DNI',
#   '9',
#   None,
#   None,
#   None,
#   'DNI'],
#  [148333,
#   'N',
#   113,
#   '43762324',
#   'RAMOS',
#   'REYES',
#   'JOSHEP IVAN',
#   'RAMOS REYES, JOSHEP IVAN',
#   None,
#   'S',
#   'M',
#   datetime.date(1986, 9, 8),
#   1,
#   10956,
#   'FACULTAD DE CIENCIAS CONTABLES',
#   '0',
#   'N',
#   None,
#   None,
#   38962,
#   None,
#   None,
#   "'43762324':5 'ivan':4 'joshep':3 'ram':1 'rey':2",
#   '0',
#   'DNI',
#   '1',
#   'F11',
#   None,
#   1955,
#   'DNI'],
#  [148331,
#   'J',
#   114,
#   '20556796140',
#   None,
#   None,
#   'PROJECT TAJAMA S.A.C.',
#   'PROJECT TAJAMA S.A.C.',
#   'Av. Republica de Chile 295 Int. 601 Santa Beatriz Lima - Lima - Lima',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20556796140',
#   'S',
#   2089,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20556796140':4 'project':1 's.a.c':3 'tajam':2",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [75850,
#   'N',
#   114,
#   '10074964562',
#   'ARANGO',
#   'NUÑEZ',
#   'ERNESTO ALFONSO',
#   'ARANGO NUÑEZ, ERNESTO ALFONSO',
#   'JR. MOYOBAMBA MZ.A LT17 URB. LA POLVORA - LA VICTORIA - LIMA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10074964562',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10074964562':5 'alfons':4 'arang':1 'ernest':3 'nuñez':2",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [144797,
#   'J',
#   114,
#   '20601212472',
#   None,
#   None,
#   'LIM KIT CORPORACION E.I.R.L.',
#   'LIM KIT CORPORACION E.I.R.L.',
#   'CAL.PROGRESO MZA. S LOTE. 08 (SECTOR 1 _ A 2CDRAS. DEL MERCADO) LIMA - LIMA - ATE',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '20601212472',
#   'S',
#   3680,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'20601212472':5 'corporacion':3 'e.i.r.l':4 'kit':2 'lim':1",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [148332,
#   'N',
#   113,
#   '10450730',
#   'CORTEZ',
#   'AMIEL',
#   'MIRIAM ADELA',
#   'CORTEZ AMIEL, MIRIAM ADELA',
#   'JR. PACASMAYO N°3702-SAN MARTIN DE PORRES-LIMA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10104507307',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10450730':5 'adel':4 'amiel':2 'cortez':1 'miriam':3",
#   '0',
#   'DNI',
#   '1',
#   None,
#   None,
#   None,
#   'DNI'],
#  [147576,
#   'J',
#   114,
#   '10096033121',
#   None,
#   None,
#   'CERCADO VASQUEZ VICTOR HUGO',
#   'CERCADO VASQUEZ VICTOR HUGO',
#   'CAL. AGUSTO AGUIRRE SOTO 3449 U,POP CONDEVILLA DEL SR. - SAN MARTIN DE PORRES',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10096033121',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10096033121':5 'cerc':1 'hug':4 'vasquez':2 'victor':3",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  [137447,
#   'J',
#   114,
#   '10296215100',
#   None,
#   None,
#   'LOPEZ CHACON MARIA SALOME',
#   'LOPEZ CHACON MARIA SALOME',
#   'PZA. MARQUINA NRO 150 DPTO 506 URB. TORRES DE LIMATAMBO SAN BORJA',
#   None,
#   None,
#   None,
#   0,
#   None,
#   None,
#   '10296215100',
#   'N',
#   None,
#   None,
#   1955,
#   'PERÚ',
#   None,
#   "'10296215100':5 'chacon':2 'lopez':1 'mari':3 'salom':4",
#   '0',
#   'RUC',
#   '1',
#   None,
#   None,
#   None,
#   'RUC'],
#  ...]
